# %% [markdown]
# # 1. Purpose of this notebook

# %% [markdown]
# To demonstrate the process of customer segmentation and its application in marketing strategies. Through concise analysis and actionable insights, it showcases how businesses can effectively categorize their customer base into distinct segments based on behavior and preferences.
#
# By understanding the unique needs of each segment, businesses can tailor their marketing efforts to maximize customer engagement, loyalty, and revenue. Overall, this analysis serves as a practical guide for implementing customer segmentation to optimize marketing strategies and enhance overall business performance.

# %% [markdown]
# # 2. Import package and data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/kaggle/input/retail-sales-dataset/retail_sales_dataset.csv')

# %%
df.shape
# Out:
# (1000, 9)

# %% [markdown]
# # 3. Preprocessing

# %%
# standardize column names
df.columns = df.columns.str.lower().str.replace(' ','_')
df.head()
# Out:
#    transaction_id        date customer_id  gender  age product_category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    quantity  price_per_unit  total_amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
print(df['gender'].value_counts(), '\n')
print(df['product_category'].value_counts())
# Out:
# gender
# Female    510
# Male      490
# Name: count, dtype: int64
#
# product_category
# Clothing       351
# Electronics    342
# Beauty         307
# Name: count, dtype: int64

# %%
print(df.customer_id.value_counts().max())
# Out:
# 1

# %% [markdown]
# There are no repeat purchases. Each customer has only one transaction. To make our RFM customer segmentation practice fun and meaningful, let's introduce multiple purchases for each customer. We re-create the customer_id column and fill a random number between 1 to 1000.

# %%
np.random.seed(101)

df['customer_id_new'] = np.random.randint(0, 500, size=1000)
df.head()
# Out:
#    transaction_id       date customer_id  gender  age product_category  \
# 0               1 2023-11-24     CUST001    Male   34           Beauty
# 1               2 2023-02-27     CUST002  Female   26         Clothing
# 2               3 2023-01-13     CUST003    Male   50      Electronics
# 3               4 2023-05-21     CUST004    Male   37         Clothing
# 4               5 2023-05-06     CUST005    Male   30           Beauty
#
#    quantity  price_per_unit  total_amount  customer_id_new
# 0         3              50           150              351
# 1         2             500          1000               11
# 2         1              30            30              337
# 3         1             500           500              326
# 4         2              50           100               63

# %%
df.customer_id_new.value_counts()
# Out:
# customer_id_new
# 383    7
# 343    7
# 133    6
# 424    6
# 215    6
#       ..
# 43     1
# 439    1
# 413    1
# 412    1
# 202    1
# Name: count, Length: 429, dtype: int64

# %% [markdown]
# Great. This better represents actual real-world data, which helps in our practice. Let's replace customer_id column with this new column.

# %%
df['customer_id_new'] = df['customer_id_new'].apply(lambda x: f'CUST{str(x).zfill(3)}')

# %%
df['customer_id'] = df['customer_id_new']
df.head()
# Out:
#    transaction_id       date customer_id  gender  age product_category  \
# 0               1 2023-11-24     CUST351    Male   34           Beauty
# 1               2 2023-02-27     CUST011  Female   26         Clothing
# 2               3 2023-01-13     CUST337    Male   50      Electronics
# 3               4 2023-05-21     CUST326    Male   37         Clothing
# 4               5 2023-05-06     CUST063    Male   30           Beauty
#
#    quantity  price_per_unit  total_amount customer_id_new
# 0         3              50           150         CUST351
# 1         2             500          1000         CUST011
# 2         1              30            30         CUST337
# 3         1             500           500         CUST326
# 4         2              50           100         CUST063

# %%
df = df.drop(columns=['customer_id_new'])
df.customer_id.value_counts().head()
# Out:
# customer_id
# CUST383    7
# CUST343    7
# CUST133    6
# CUST424    6
# CUST215    6
# Name: count, dtype: int64

# %% [markdown]
# # 4. RFM Customer Segmentation

# %% [markdown]
# RFM (Recency, Frequency, Monetary) customer segmentation is a marketing analysis tool that categorizes customers based on how recently they made a purchase, how often they purchase, and how much they spend. This method helps businesses identify their most valuable customers, understand buying patterns, and tailor marketing strategies to boost customer retention and maximize revenue. By focusing on the most profitable segments, RFM segmentation enhances personalized communication and marketing efficiency.

# %%
max_date = df['date'].max()
max_date
# Out:
# Timestamp('2024-01-01 00:00:00')

# %%
# create customer-level dataset
customer_data = df.groupby('customer_id').agg({
    'date': lambda x: (max_date - x.max()).days,  # recency
    'transaction_id': 'count',  # frequency
    'total_amount': 'sum'  # monetary
})

# %%
customer_data.rename(columns={
    'date': 'recency',
    'transaction_id': 'frequency',
    'total_amount': 'monetary'
}, inplace=True)

customer_data.head()
# Out:
#              recency  frequency  monetary
# customer_id
# CUST000          325          2       800
# CUST001           56          2      1800
# CUST002           91          2       250
# CUST003          292          2      1090
# CUST004           81          3      1210

# %%
# assign scores to each RFM component
quantiles = customer_data.quantile(q=[.25, .5, .75])
quantiles = quantiles.to_dict()

# %%
quantiles
# Out:
# {'recency': {0.25: 45.0, 0.5: 105.0, 0.75: 202.0},
#  'frequency': {0.25: 1.0, 0.5: 2.0, 0.75: 3.0},
#  'monetary': {0.25: 175.0, 0.5: 920.0, 0.75: 1575.0}}

# %%
def RScore(x, a, b):
    if x <= a:
        return 5
    elif a < x <= b:
        return 4
    elif b < x <= quantiles['monetary'][0.75]:
        return 3
    elif quantiles['monetary'][0.75] < x <= quantiles['frequency'][0.75]:
        return 2
    else:
        return 1

def FMScore(x, a, b): # frequency and monetary: higher better
    if x <= a:
        return 1
    elif a < x <= b:
        return 2
    elif b < x <= quantiles['frequency'][0.75]:
        return 3
    elif quantiles['frequency'][0.75] < x <= quantiles['monetary'][0.75]:
        return 4
    else:
        return 5

# %%
customer_data['R_Score'] = customer_data['recency'].apply(RScore, args=(quantiles['recency'][0.25], quantiles['recency'][0.5]))
customer_data['F_Score'] = customer_data['frequency'].apply(FMScore, args=(quantiles['frequency'][0.25], quantiles['frequency'][0.5]))
customer_data['M_Score'] = customer_data['monetary'].apply(RScore, args=(quantiles['monetary'][0.25], quantiles['monetary'][0.5]))

# %%
# calculate RFM score for each customer
customer_data['RFM_Score'] = customer_data['R_Score'].astype(str) + customer_data['F_Score'].astype(str) + customer_data['M_Score'].astype(str)
customer_data.head()
# Out:
#              recency  frequency  monetary  R_Score  F_Score  M_Score RFM_Score
# customer_id
# CUST000          325          2       800        3        2        4       324
# CUST001           56          2      1800        4        2        1       421
# CUST002           91          2       250        4        2        4       424
# CUST003          292          2      1090        3        2        3       323
# CUST004           81          3      1210        4        3        3       433

# %%
plt.figure(figsize=(10,4))
rfm_level_counts = customer_data['RFM_Score'].value_counts().sort_index()
sns.barplot(x=rfm_level_counts.index, y=rfm_level_counts.values)
plt.title('Distribution of RFM Scores')
plt.xlabel('RFM Score')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### K Means Clustering

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

scaler = StandardScaler()
rfm_scaled = scaler.fit_transform(customer_data[['R_Score', 'F_Score', 'M_Score']])

inertia = []
K = range(1, 11)

for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(rfm_scaled)
    inertia.append(kmeans.inertia_)

# elbow curve to choose optimal clusters
plt.figure(figsize=(6, 4))
plt.plot(K, inertia, 'bo-')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal k')
plt.show()

# %%
kmeans = KMeans(n_clusters=4, random_state=42)
customer_data['Cluster'] = kmeans.fit_predict(rfm_scaled)

# %%
cluster_summary = customer_data.groupby('Cluster').agg({
    'R_Score': 'mean',
    'F_Score': 'mean',
    'M_Score': 'mean'
}).reset_index()

# %%
cluster_summary
# Out:
#    Cluster   R_Score   F_Score   M_Score
# 0        0  3.072917  2.541667  2.322917
# 1        1  4.570175  2.377193  3.833333
# 2        2  3.125874  1.195804  4.468531
# 3        3  4.578947  3.578947  1.289474

# %%
# Assigning the segment names
segment_names = {
    0: 'At Risk',
    1: 'Recent Customers',
    2: 'Big Spenders',
    3: 'Frequent Low Spenders'
}

# Assign the segment names to the Cluster
customer_data['Segment'] = customer_data['Cluster'].map(segment_names)

# Display the customer data with segments
customer_data[['R_Score', 'F_Score', 'M_Score', 'RFM_Score', 'Cluster', 'Segment']].head()
# Out:
#              R_Score  F_Score  M_Score RFM_Score  Cluster           Segment
# customer_id
# CUST000            3        2        4       324        2      Big Spenders
# CUST001            4        2        1       421        0           At Risk
# CUST002            4        2        4       424        1  Recent Customers
# CUST003            3        2        3       323        0           At Risk
# CUST004            4        3        3       433        1  Recent Customers

# %%
# size of each segment
segment_size = customer_data['Segment'].value_counts().reset_index()
segment_size.columns = ['Segment','Count']
segment_size
# Out:
#                  Segment  Count
# 0           Big Spenders    143
# 1       Recent Customers    114
# 2                At Risk     96
# 3  Frequent Low Spenders     76

# %%
plt.figure(figsize=(7,3))
sns.countplot(data=customer_data, x='Segment', order=segment_size['Segment'])
plt.title('Customer Segments Distribution')
plt.xlabel('Segment')
plt.ylabel('Number of Customers')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 5. Recommendations

# %% [markdown]
# **Big Spenders (143 customers):**
#
# Implement exclusive offers and VIP perks to capitalize on their high spending.
# Provide personalized product recommendations to encourage further purchases.
# Focus on exceptional customer service to reinforce loyalty and encourage repeat business.
#
# **Recent Customers (114 customers):**
#
# Nurture relationships with welcome emails and personalized recommendations.
# Offer incentives like discounts or referral bonuses to encourage continued engagement.
# Gather feedback through surveys to improve their experience and foster loyalty.
#
# **At Risk (96 customers):**
#
# Launch reactivation campaigns with personalized offers and promotions.
# Address concerns and rebuild trust through targeted communication.
# Collect feedback to identify pain points and improve satisfaction.
#
# **Frequent Low Spenders (76 customers):**
#
# Encourage larger purchases through upselling and cross-selling strategies.
# Offer bundle deals or loyalty rewards to incentivize increased spending.
# Build loyalty through personalized communication and tailored promotions.

# %% [markdown]
# Tailoring marketing strategies to each segment maximizes customer lifetime value and fosters long-term loyalty. Regular analysis ensures adaptability to evolving preferences, driving sustainable growth.
